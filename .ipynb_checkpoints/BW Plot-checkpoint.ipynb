# %%
import pickle

# %%
a = pickle.load(open('./xkatest.p','rb'))

# %%
import pandas as pd

# %%
df = pd.DataFrame(a)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('talk')

# %%
plt.plot(2**df['alpha'],label=r'$\alpha$')
plt.plot(2**df['beta'],label=r'$\beta$')
plt.legend()
plt.ylabel('parameter value')
plt.xlabel('Baum-Welch Iterations')
plt.title('Repeat D')
plt.tight_layout()
plt.savefig('./repeatD_xka.pdf',bbox_inches='tight')
