# %%
import numpy as np
import seaborn as sns
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('./scoreDist.txt')

# %%
parameters = norm.fit(data)

x = np.linspace(-10,100,2192)
dist = norm.pdf(x,loc=parameters[0],scale=parameters[1])

# %%
sns.distplot(data)
#plt.plot(x,dist)
